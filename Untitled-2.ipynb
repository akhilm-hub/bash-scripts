# %%
# %%bash
#
# echo "====================="
# echo "SYSTEM REPORT"
# echo "====================="
#
# echo
# echo "current user:"
# whoami
#
# echo
# echo "CURRENT Directory"
# pwd
#
# echo
# echo "list files"
# ls
#
# echo
# echo "disk space"
# df -h
#
# echo
# echo "memeory usage"
# free -h
# Out:
# =====================
# SYSTEM REPORT
# =====================
#
# current user:
# akhilm
#
# CURRENT Directory
# /home/akhilm
#
# list files
# akh.py
# akh.sh
# akil
# akk
# assh
# backup.sh
# calculator.sh
# check_site.py
# Desktop
# DOCUMENTATION OF VLAN AND SUBNET.pdf
# DOCUMENTATION OF VLAN AND SUBNET.zip
# Documents
# downloads
# Downloads
# error.txt
# evenodd.sh
# hello.sh
# kb.sh
# my-ai-project
# my-web-server
# net_check.sh
# no-mistakes
# no-mistakes-test
# no mistake task .pdf
# Pictures
# pp.py
# salary.txt
# signal-2026-06-20-102051_002.jpeg
# signal-2026-06-20-190625_002.png
# signal-2026-06-26-101237_002.png
# snap
# sort_downloads.sh
# students.txt
# test.txt
# tps.txt
# user-auth-system
# VirtualBox VMs
# vlsm.py
# Walls.zip
# Win11_25H2_English_x64_v2.iso
#
# disk space
# Filesystem      Size  Used Avail Use% Mounted on
# tmpfs           1.6G  3.4M  1.6G   1% /run
# /dev/nvme0n1p2  468G  218G  227G  49% /
# tmpfs           7.7G   56M  7.7G   1% /dev/shm
# tmpfs           5.0M  4.0K  5.0M   1% /run/lock
# efivarfs        438K  186K  248K  43% /sys/firmware/efi/efivars
# /dev/nvme0n1p1  511M  6.1M  505M   2% /boot/efi
# tmpfs           1.6G  5.5M  1.6G   1% /run/user/1001
#
# memeory usage
#                total        used        free      shared  buff/cache   available
# Mem:            15Gi        10Gi       506Mi       1.7Gi       4.2Gi       3.2Gi
# Swap:          2.0Gi       1.8Gi       238Mi

# %%
# %%bash
#
# num=12
#
# read -p "enter the number:" num
#
# if [ $((num % 2)) -eq 0 ]
# then
#     echo "even"
# else
#     echo "odd"
#
# fi
# Out:
# even

# %%
# %%bash
#
# read -p "enter the number " num
#
# if [ $num -gt 0 ]
# then
#     echo "$num is positive"
#
# elif [ $num -lt o ]
# then
#     echo "$num is negative"
#
# else
#     echo "$num is zero"
#
#
# fi
# Out:
# bash: line 3: [: -gt: unary operator expected
# bash: line 7: [: -lt: unary operator expected
#  is zero

# %%
# %%bash
#
# read -p "Enter a number: " num
#
# if [ $num -gt 0 ]
# then
#     echo "$num is Positive"
#
# elif [ $num -lt 0 ]
# then
#     echo "$num is Negative"
#
# else
#     echo "$num is Zero"
#
# fi
# Out:
# bash: line 3: [: -gt: unary operator expected
# bash: line 7: [: -lt: unary operator expected
#  is Zero

# %%
# %%bash
#
# read -p "enter the age:" age
# echo "age entered: $age"
#
# if [ $age -ge 18 ]
# then
#     echo "eligible to vote"
# else
#     echo "not eligible"
# fi
# Out:
# bash: line 4: [: too many arguments
# not eligible

# %%
# %%bash
#
# read -p "Enter your age: " age
#
# echo "Age entered: $age"
#
# if [ $age -ge 18 ]
# then
#     echo "Eligible"
# else
#     echo "Not Eligible"
# fi
# `
# Out:
# Age entered:
# bash: line 5: [: -ge: unary operator expected
# bash: line 11: unexpected EOF while looking for matching ``'
# bash: line 13: syntax error: unexpected end of file
# Not Eligible
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', '\nread -p "Enter your age: " age\n\necho "Age entered: $age"\n\nif [ $age -ge 18 ]\nthen\n    echo "Eligible"\nelse\n    echo "Not Eligible"\nfi\n`\n\n')
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2543, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2541 with self.builtin_trap:
#    2542     args = (magic_arg_s, cell)
# -> 2543     result = fn(*args, **kwargs)
#    2545 # The code below prevents the output from being displayed
#    2546 # when using magics with decorator @output_can_be_silenced
#    2547 # when the last Python token in the expression is a ';'.
#    2548 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/magics/script.py:159, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     157 else:
#     158     line = script
# --> 159 return self.shebang(line, cell)
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/magics/script.py:336, in ScriptMagics.shebang(self, line, cell)
#     331 if args.raise_error and p.returncode != 0:
#     332     # If we get here and p.returncode is still None, we must have
#     333     # killed it but not yet seen its return code. We don't wait for it,
#     334     # in case it's stuck in uninterruptible sleep. -9 = SIGKILL
#     335     rc = p.returncode or -9
# --> 336     raise CalledProcessError(rc, cell)
#
# CalledProcessError: Command 'b'\nread -p "Enter your age: " age\n\necho "Age entered: $age"\n\nif [ $age -ge 18 ]\nthen\n    echo "Eligible"\nelse\n    echo "Not Eligible"\nfi\n`\n\n'' returned non-zero exit status 2.

# %%
# %%bash
# Out:
# UsageError: %%bash is a cell magic, but the cell body is empty.

# %%
# %%bash
#
# #!/bin/bash
#
# age=20
#
# if [ $age -ge 18 ]
# then
#     echo "Eligible to Vote"
# else
#     echo "Not Eligible to Vote"
# fi
#
# `
# Out:
# Eligible to Vote
# bash: line 13: unexpected EOF while looking for matching ``'
# bash: line 14: syntax error: unexpected end of file
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', '\n#!/bin/bash\n\nage=20\n\nif [ $age -ge 18 ]\nthen\n    echo "Eligible to Vote"\nelse\n    echo "Not Eligible to Vote"\nfi\n\n`\n')
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:2543, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2541 with self.builtin_trap:
#    2542     args = (magic_arg_s, cell)
# -> 2543     result = fn(*args, **kwargs)
#    2545 # The code below prevents the output from being displayed
#    2546 # when using magics with decorator @output_can_be_silenced
#    2547 # when the last Python token in the expression is a ';'.
#    2548 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/magics/script.py:159, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     157 else:
#     158     line = script
# --> 159 return self.shebang(line, cell)
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/magics/script.py:336, in ScriptMagics.shebang(self, line, cell)
#     331 if args.raise_error and p.returncode != 0:
#     332     # If we get here and p.returncode is still None, we must have
#     333     # killed it but not yet seen its return code. We don't wait for it,
#     334     # in case it's stuck in uninterruptible sleep. -9 = SIGKILL
#     335     rc = p.returncode or -9
# --> 336     raise CalledProcessError(rc, cell)
#
# CalledProcessError: Command 'b'\n#!/bin/bash\n\nage=20\n\nif [ $age -ge 18 ]\nthen\n    echo "Eligible to Vote"\nelse\n    echo "Not Eligible to Vote"\nfi\n\n`\n'' returned non-zero exit status 2.

# %%
# %%bash
# echo -n "Enter your age: "
# read age
#
# if [ "$age" -ge 18 ];
# then
#     echo "You are eligible to vote!"
# else
#     years_left=$((18 - age))
#     echo "Not eligible. You can vote in $years_left year(s)."
# fi
# Out:
# Enter your age:
# bash: line 3: [: : integer expression expected
# Not eligible. You can vote in 18 year(s).

# %%
# %%bash
#
# for i in {i....10}
# do
#     echo $i
# done
# Out:
# {i....10}

# %%
# %%bash
#
# read -p "Enter account balance: " balance
# read -p "Enter withdrawal amount: " amount
#
# if [ $amount -le $balance ]
# then
#     remaining=$((balance - amount))
#     echo "Withdrawal Successful"
#     echo "Remaining Balance = $remaining"
# else
#     echo "Insufficient Balance"
# fi
# Out:
# bash: line 4: [: too many arguments
# Insufficient Balance

# %%
# %%bash
#
# balance=5000
# amount=2000
#
# if [ $amount -le $balance ]
# then
#     remaining=$((balance - amount))
#
#     echo "Withdrawal Successful"
#     echo "Remaining Balance = $remaining"
# else
#     echo "Insufficient Balance"
# fi

# %%
# %%bash
#
# echo "enter a number"
# read num
#
# if [ $((num % 2)) -eq 0]
# then
#     echo "even"
# else
#     echo  "odd"
# fi
